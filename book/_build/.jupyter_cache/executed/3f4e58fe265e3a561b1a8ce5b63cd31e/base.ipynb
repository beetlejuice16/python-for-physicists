# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = [0, 1, 2, 3, 4, 5]
y = [3, 4, 5, 6, 7, 8]

# %%
plt.plot(x, y)

# %%
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('My Plot')
# Out:
# Text(0.5, 1.0, 'My Plot')
